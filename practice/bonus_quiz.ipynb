# %%
result = 0
for x in [3,3,5]:
    if x > 3:
        result = result - x
    else:
        result = result + x
result
# Out:
# 1

# %%
result = {4,5,6,6,7,8}
result
# Out:
# {4, 5, 6, 7, 8}

# %%
result = 0
x = (2,3,4,5)
for i in range(1):
    result = result + x[i]
result
# Out:
# 2

# %%
import numpy as np
result = np.array([2,3,4])
result = result**2
result
# Out:
# array([ 4,  9, 16])

# %%
result = {1: "Hello", 23: "World"}
for x in result:
    print(x)
# Out:
# 1
# 23

# %%
print("1\n23")
# Out:
# 1
# 23

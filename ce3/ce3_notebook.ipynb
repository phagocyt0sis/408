# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import folium

# %%
madisonCoRoads = gpd.read_file(r"C:\Users\cquering\Documents\Repository\408\ce3\tl_2025_01089_roads.shp")

# %%
madisonCoRoads.plot()
# Out:
# <Axes: >

# %%
madisonCoRoads.groupby(["FULLNAME"])
madisonCoRoads['FULLNAME'].value_counts()
# Out:
# FULLNAME
# US Hwy 431             30
# State Rte 1            30
# Nature Walk Blvd SW    27
# US Hwy 72              21
# State Rte 2            21
#                        ..
# Interpro Dr             1
# Pintail Pointe Cir      1
# Herrick Dr              1
# Oregon Dr               1
# Erskin Parcus Dr        1
# Name: count, Length: 7348, dtype: int64

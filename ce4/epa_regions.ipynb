# %%
import geopandas as gpd
import pandas as pd

epa_files = gpd.read_file(r"C:\Users\cquering\Documents\Repository\408\ce4\lvl3_ecoregion\us_eco_l3_state_boundaries.shp")
epa_files.plot(column='EPA_REGION', cmap = 'cool')
# Out:
# <Axes: >
